# %% [markdown]
# <a href="https://colab.research.google.com/github/mana629/-Fundamentals-of-genai-/blob/main/RAG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lagchain-core
# Out:
# ERROR: Could not find a version that satisfies the requirement lagchain-core (from versions: none)
# ERROR: No matching distribution found for lagchain-core

# %%
# !pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformers chromadb

# %%
from langchain_core.documents import Document

# %%
from langchain_core.documents import Document
doc = Document(
        page_content="Hello, world!", metadata={"source": "https://www.google.com"}
    )

# %%
type(doc)
# Out:
# langchain_core.documents.base.Document

# %%
from langchain_community.document_loaders.text import TextLoader
loader = TextLoader("Python.txt" , encoding = "utf-8")

# %%
document = loader.load()

# %%
#pdf data
from langchain_community.document_loaders.pdf import PyPDFLoader
pdf_load =  PyPDFLoader("research2.pdf")

# %%
document = pdf_load.load()

# %%
# INGESTION PIPLINE

# %%
import os
from langchain_community.document_loaders.pdf import PyPDFLoader

# %%
def load_all_pdfs():
  folder_path = "data/pdfs"
  num_docs = 0
  all_docs = []

  # Create the folder if it doesn't exist


  for filename in os.listdir(folder_path):
    if filename.lower().endswith(".pdf"):

      pdf_path = os.path.join(folder_path, filename)
      loader = PyPDFLoader(pdf_path)
      docs = loader.load()

      all_docs.extend(doc)
      num_docs += 1

      print("total pdfs", num_docs)
      print("total pages", len(all_docs))
      return all_docs

# %%
all_pdf_documents = load_all_pdfs()
# Out:
# total pdfs 1
# total pages 4

# %%
print(all_pdf_documents)
# Out:
# [('id', None), ('metadata', {'source': 'https://www.google.com'}), ('page_content', 'Hello, world!'), ('type', 'Document')]

# %%
from google.colab import drive
drive.mount('/content/drive')
